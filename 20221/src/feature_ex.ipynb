# %%
# importing sys
import sys
  
# adding srcpy to the system path
sys.path.insert(0, "/Users/charles/Desktop/DSAI/6_DataScience/project/DSP/zr1/src/srcpy")

import data_proc

# Auto reload: watch a directory for changed files and restarts a process when the change is detected
# %load_ext autoreload
# %autoreload 2

# %%
import random
import numpy as np
import pandas as pd
pd.options.display.max_columns = None
pd.options.mode.chained_assignment = None
pd.options.display.float_format

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
mpl.style.use("ggplot")
pylab.rcParams["figure.figsize"] = 8 , 6

import seaborn as sns
sns.set_style("white")

from pandas_profiling import ProfileReport

# %%
df = data_proc.load_training_data("/Users/charles/Desktop/DSAI/6_DataScience/project/DSP/20221/data/zillow.csv")
df = df.drop(['Unnamed: 0', "type", "rent_zestimate", "zestimate", "broker_name", "full_bathrooms"], axis=1)
df.head()
# Out:
#      price          status  has_add_attributions              city state  \
# 0   274000  House for sale                  True  South Ozone Park    NY
# 1   270000  House for sale                  True           Jamaica    NY
# 2   899000  House for sale                  True     Staten Island    NY
# 3  1390000  House for sale                  True          Flushing    NY
# 4  1390000  House for sale                  True          Flushing    NY
#
#     latitude  longitude  bathrooms  bedrooms  living_area  lot_area  \
# 0  40.675730 -73.822350          1         3         1556    2400.0
# 1  40.670036 -73.780450          2         4         1920    3998.0
# 2  40.524227 -74.215790          3         3         2532    6903.0
# 3  40.721615 -73.820755          4         4         1915    2697.0
# 4  40.721615 -73.820755          4         4         1915    2697.0
#
#    tax_assessed_value num_fireplaces            parking  covered_spaces  \
# 0                   0           none  Garage - Detached           1.750
# 1              678000           none               none           1.660
# 2              637000           none            Detache           1.935
# 3              894000           none               none           1.695
# 4                   0           none     Shared Drivewa           1.540
#
#    garage_spaces  total_spaces         lot_features                   subtype  \
# 0          1.595         1.945                 none                      none
# 1          1.535         2.160                 none                      none
# 2          2.000         2.000                 none  Single Family - Detached
# 3          1.655         3.915                 none                      none
# 4          1.000         3.705  Near Public Transit   Single Family Residence
#
#   architectural_style  year_built    sewer_info water_info  appliances  \
# 0                none      1930.0          none       none        none
# 1                none      1950.0          none       none   microwave
# 2            Colonial      1899.0  Public Sewer       none  dishwasher
# 3                none      1945.0          none       none       dryer
# 4       Semi Detached      1945.0  Public Sewer     Public        none
#
#        heating       cooling  stories materials  roof foundation  \
# 0         none          none      0.0      none  none       none
# 1         none          none      0.0      none  none       none
# 2    hot water         Units      2.0      none  none       none
# 3         none          none      0.0      none  none       none
# 4  natural gas  Wall Unit(s)      3.0     frame  none       none
#
#   interior_features compensation
# 0              none         none
# 1              none         none
# 2              none         none
# 3              none         none
# 4     Eat-in Kitche         none

# %%
print("Number of house: {}".format(len(df)))
# Out:
# Number of house: 13339
